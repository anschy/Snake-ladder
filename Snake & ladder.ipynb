# %%
snake = {17 : 7, 54 : 34, 62 : 19, 98 : 79}
ladder = {3 : 38, 24 : 33, 42 : 93, 72 : 84}

snake.update(ladder)


def auto():
    i = 0
    j = 0
    while (i or j) < 100:
        player1 = input("player1 : ").lower()
        if player1 == "roll":
            num = random.randint(1,6)
            print("You got a ",num)
            i = i+num
            for key in snake:
                if i == key:
                    i = snake[key]
                else:
                    i = i
            if i >= 100:
                print("Congratulations player 1 won the game!!!")
                print("Game Successfully Finished")
                print("Exiting the game...")
                break
            else:
                print('Your final position is ',i)
                print('-'*50)
                
        elif player1=='quit':
            print("Player 2 has won the game")
            print("Game Successfully Finished")
            break
        else:
            print('It seems you typed the wrong keyword!!! Please type "roll" to roll a dice or "quit" or exit the game, excluding qoutation marks.')
 

        player2 = input("player2 : ").lower()
        if player2 == "roll":
            num = random.randint(1,6)
            print("You got a ",num)
            j = j+num
            for key in snake:
                if j == key:
                    j = snake[key]
                else:
                    j = j
            if j >= 100:
                print("congratulations player 2 won the game!!!")
                print("Game Successfully Finished")
                print("Exiting the game...")
                break
            else:
                print('Your final position is ',j)
                print('-'*50)
                
        elif player2=='quit':
            print("Player 1 has won the game")
            print("Game Successfully Finished")
            break
        else:
            print('It seems you typed the wrong keyword!!! Please type "roll" to roll a dice or "quit" or exit the game, excluding qoutation marks.')

def manual():
    i = 0
    j = 0
    while (i or j) < 100:
        num = input("Player 1 - Enter the number of your choice betweeen 1-20 : ")
        if num == "quit":
            print("Player 2 has won the game")
            print("Game Successfully Finished")
            break
        elif int(num) > 20 or int(num) < 1:
            print('you have entered the number that does not exits in the range of 1-20')
        else:
            num = int(num)
            print("You got a ",num)
            i = i+num
            for key in snake:
                if i == key:
                    i = snake[key]
                else:
                    i = i
            if i >= 100:
                print("Congratulations player 1 won the game!!!")
                print("Game Successfully Finished")
                print("Exiting the game...")
                break
            else:
                print('Your final position is ',i)
                print('-'*50)
                                

        num = input("Player 2 - Enter the number of your choice betweeen 1-20 : ")
        if num == "quit":
            print("Player 1 has won the game")
            print("Game Successfully Finished")
            break
        elif int(num) > 20 or int(num) < 1:
            print('you have entered the number that does not exits in the range of 1-20')
        else:
            num = int(num)
            print("You got a ",num)
            j = j+num
            for key in snake:
                if j == key:
                    j = snake[key]
                else:
                    j = j
            if j >= 100:
                print("congratulations player 2 won the game!!!")
                print("Game Successfully Finished")
                print("Exiting the game...")
                break
            else:
                print('Your final position is ',j)
                print('-'*50)
                    
import random

print(":: Welcome to Snake and Ladder game ::")
player_1 = input("Enter the name of player 1 : ")
player_2 = input("Enter the name of player 2 : ")
print("       How do you wanna play?")

mode = input("Please type Auto or Manual to play in that mode - ").lower()


if mode=='auto':
    print('starting Auto mode')
    auto()
elif mode == "manual":
    print('starting Manual mode')
    manual()
else:
    print("wrong mode entered.")
# Out:
# :: Welcome to Snake and Ladder game ::
# Enter the name of player 1 : quit
# Enter the name of player 2 : quit
#        How do you wanna play?
# Please type Auto or Manual to play in that mode - quit
# wrong mode entered.
